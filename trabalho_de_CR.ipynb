# %% [markdown]
# <a href="https://colab.research.google.com/github/sanchezyasmin/projeto-comunicacao-e-redes/blob/main/trabalho_de_CR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
facet = ([("Facet", "Velvereen"), ("Facet", "Sabyn"),("Facet", "Marcus"), ("Facet", "Teslee"), ("Facet", "Circ"), ("Facet", "Coral"),
("Facet", "Mizzen"), ("Facet", "Sol"), ("Facet", "Hy"), ("Facet", "Ginnee"), ("Facet", "Otto"),("Facet", "Lamina"), ("Facet", "Treach"),
("Facet", "Wovey"), ("Facet", "Bobbin"), ("Facet", "Panlo"), ("Facet", "Sheaf"), ("Facet", "Brandy"), ("Facet", "Tanner"),
("Facet", "Dill"), ("Facet", "Reaper Ash"), ("Facet", "Lucy Gray"), ("Facet", "Jessup Diggs"), ("Facet", "Livia Cardew"), ("Facet", "Coriolanus")])

# %%
valvereen = ([("Velvereen", "Sabyn"),("Velvereen", "Marcus"), ("Velvereen", "Teslee"), ("Velvereen", "Circ"), ("Velvereen", "Coral"),
("Velvereen", "Mizzen"), ("Velvereen", "Sol"), ("Velvereen", "Hy"), ("Velvereen", "Ginnee"), ("Velvereen", "Otto"),("Velvereen", "Lamina"), ("Velvereen", "Treach"),
("Velvereen", "Wovey"), ("Velvereen", "Bobbin"), ("Velvereen", "Panlo"), ("Velvereen", "Sheaf"), ("Velvereen", "Brandy"), ("Velvereen", "Tanner"),
("Velvereen", "Dill"), ("Velvereen", "Reaper Ash"), ("Velvereen", "Lucy Gray"), ("Velvereen", "Jessup Diggs"), ("Velvereen", "Palmyra"), ("Velvereen", "Coriolanus")])

# %%
sabyn = ([("Sabyn", "Marcus"), ("Sabyn", "Teslee"), ("Sabyn", "Circ"), ("Sabyn", "Coral"),
("Sabyn", "Mizzen"), ("Sabyn", "Sol"), ("Sabyn", "Hy"), ("Sabyn", "Ginnee"), ("Sabyn", "Otto"),("Sabyn", "Lamina"), ("Sabyn", "Treach"),
("Sabyn", "Wovey"), ("Sabyn", "Bobbin"), ("Sabyn", "Panlo"), ("Sabyn", "Sheaf"), ("Sabyn", "Brandy"), ("Sabyn", "Tanner"),
("Sabyn", "Dill"), ("Sabyn", "Reaper Ash"), ("Sabyn", "Lucy Gray"), ("Sabyn", "Jessup Diggs"), ("Sabyn", "Florus"), ("Sabyn", "Coriolanus")])

# %%
marcus = ([("Marcus", "Teslee"), ("Marcus", "Circ"), ("Marcus", "Coral"),
("Marcus", "Mizzen"), ("Marcus", "Sol"), ("Marcus", "Hy"), ("Marcus", "Ginnee"), ("Marcus", "Otto"),("Marcus", "Lamina"), ("Marcus", "Treach"),
("Marcus", "Wovey"), ("Marcus", "Bobbin"), ("Marcus", "Panlo"), ("Marcus", "Sheaf"), ("Marcus", "Brandy"), ("Marcus", "Tanner"),
("Marcus", "Dill"), ("Marcus", "Reaper Ash"), ("Marcus", "Lucy Gray"), ("Marcus", "Jessup Diggs"), ("Marcus", "Sejanus"), ("Marcus", "Coriolanus")])

# %%
teslee = ([("Teslee", "Circ"), ("Teslee", "Coral"),
("Teslee", "Mizzen"), ("Teslee", "Sol"), ("Teslee", "Hy"), ("Teslee", "Ginnee"), ("Teslee", "Otto"),("Teslee", "Lamina"), ("Teslee", "Treach"),
("Teslee", "Wovey"), ("Teslee", "Bobbin"), ("Teslee", "Panlo"), ("Teslee", "Sheaf"), ("Teslee", "Brandy"), ("Teslee", "Tanner"),
("Teslee", "Dill"), ("Teslee", "Reaper Ash"), ("Teslee", "Lucy Gray"), ("Teslee", "Jessup Diggs"),("Teslee", "Urban Canville"),
           ("Teslee", "Coriolanus")])

# %%
circ = ([("Circ", "Mizzen"), ("Circ", "Coral"), ("Circ", "Sol"), ("Circ", "Hy"), ("Circ", "Ginnee"),
("Circ", "Otto"),("Circ", "Lamina"), ("Circ", "Treach"),("Circ", "Wovey"), ("Circ", "Bobbin"),
("Circ", "Panlo"), ("Circ", "Sheaf"), ("Circ", "Brandy"), ("Circ", "Tanner"),
("Circ", "Dill"), ("Circ", "Reaper Ash"), ("Circ", "Lucy Gray"), ("Circ", "Jessup Diggs"), ("Circ", "Io Jasper"),
         ("Circ", "Coriolanus")])

# %%
mizzen = ([("Mizzen", "Sol"), ("Mizzen", "Hy"), ("Mizzen", "Ginnee"),
("Mizzen", "Otto"),("Mizzen", "Lamina"), ("Mizzen", "Treach"),("Mizzen", "Wovey"), ("Mizzen", "Bobbin"),
("Mizzen", "Panlo"), ("Mizzen", "Sheaf"), ("Mizzen", "Brandy"), ("Mizzen", "Tanner"),
("Mizzen", "Dill"), ("Mizzen", "Reaper Ash"), ("Mizzen", "Lucy Gray"), ("Mizzen", "Jessup Diggs"), ("Mizzen", "Coral"), ("Mizzen", "Persephone"),
           ("Mizzen", "Coriolanus")])

# %%
sol = ([("Sol", "Hy"), ("Sol", "Ginnee"),
("Sol", "Otto"),("Sol", "Lamina"), ("Sol", "Treach"),("Sol", "Wovey"), ("Sol", "Bobbin"),
("Sol", "Panlo"), ("Sol", "Sheaf"), ("Sol", "Brandy"), ("Sol", "Tanner"),
("Sol", "Dill"), ("Sol", "Reaper Ash"), ("Sol", "Lucy Gray"), ("Sol", "Jessup Diggs"), ("Sol", "Coral"), ("Sol", "Iphigenia"), ("Sol", "Coriolanus")])

# %%
hy = ([("Hy", "Ginnee"), ("Hy", "Otto"),("Hy", "Lamina"), ("Hy", "Treach"),("Hy", "Wovey"), ("Hy", "Bobbin"),
("Hy", "Panlo"), ("Hy", "Sheaf"), ("Hy", "Brandy"), ("Hy", "Tanner"),
("Hy", "Dill"), ("Hy", "Reaper Ash"), ("Hy", "Lucy Gray"), ("Hy", "Jessup Diggs"), ("Hy", "Coral"), ("Hy", "Dennis"), ("Hy", "Coriolanus")])

# %%
ginnee = ([("Ginnee", "Otto"),("Ginnee", "Lamina"), ("Ginnee", "Treach"),("Ginnee", "Wovey"), ("Ginnee", "Bobbin"),
("Ginnee", "Panlo"), ("Ginnee", "Sheaf"), ("Ginnee", "Brandy"), ("Ginnee", "Tanner"),
("Ginnee", "Dill"), ("Ginnee", "Reaper Ash"), ("Ginnee", "Lucy Gray"), ("Ginnee", "Jessup Diggs"), ("Ginnee", "Coral"), ("Ginnee", "Diana"),
           ("Ginnee", "Coriolanus")])

# %%
otto = ([("Otto", "Lamina"), ("Otto", "Treach"),("Otto", "Wovey"), ("Otto", "Bobbin"),
("Otto", "Panlo"), ("Otto", "Sheaf"), ("Otto", "Brandy"), ("Otto", "Tanner"),
("Otto", "Dill"), ("Otto", "Reaper Ash"), ("Otto", "Lucy Gray"), ("Otto", "Jessup Diggs"), ("Otto", "Coral"), ("Otto", "Apollo"), ("Otto", "Coriolanus")])

# %%
lamina = ([("Lamina", "Treach"),("Lamina", "Wovey"), ("Lamina", "Bobbin"),
("Lamina", "Panlo"), ("Lamina", "Sheaf"), ("Lamina", "Brandy"), ("Lamina", "Tanner"),
("Lamina", "Dill"), ("Lamina", "Reaper Ash"), ("Lamina", "Lucy Gray"), ("Lamina", "Jessup Diggs"), ("Lamina", "Coral"), ("Lamina", "Pliny"),
           ("Lamina", "Coriolanus")])

# %%
treach = ([("Treach", "Wovey"), ("Treach", "Bobbin"),
("Treach", "Panlo"), ("Treach", "Sheaf"), ("Treach", "Brandy"), ("Treach", "Tanner"),
("Treach", "Dill"), ("Treach", "Reaper Ash"), ("Treach", "Lucy Gray"), ("Treach", "Jessup Diggs"), ("Treach", "Coral"), ("Treach", "Vipsania"),
           ("Treach", "Coriolanus")])

# %%
wovey = ([("Wovey","Bobbin"),
("Wovey", "Panlo"), ("Wovey", "Sheaf"), ("Wovey", "Brandy"), ("Wovey", "Tanner"),
("Wovey", "Dill"), ("Wovey", "Reaper Ash"), ("Wovey", "Lucy Gray"), ("Wovey", "Jessup Diggs"), ("Wovey", "Coral"), ("Wovey", "Hilarius"),
          ("Wovey", "Coriolanus")])

# %%
bobbin = ([("Bobbin", "Panlo"), ("Bobbin", "Sheaf"), ("Bobbin", "Brandy"), ("Bobbin", "Tanner"),
("Bobbin", "Dill"), ("Bobbin", "Reaper Ash"), ("Bobbin", "Lucy Gray"), ("Bobbin", "Jessup Diggs"), ("Bobbin", "Coral"), ("Bobbin", "Juno"), ("Bobbin", "Coriolanus")])

# %%
panlo = ([("Panlo", "Sheaf"), ("Panlo", "Brandy"), ("Panlo", "Tanner"),
("Panlo", "Dill"), ("Panlo", "Reaper Ash"), ("Panlo", "Lucy Gray"), ("Panlo", "Jessup Diggs"), ("Panlo", "Coral"), ("Panlo", "Gaius"), ("Panlo", "Coriolanus")])

# %%
sheaf = ([("Sheaf", "Brandy"), ("Sheaf", "Tanner"),
("Sheaf", "Dill"), ("Sheaf", "Reaper Ash"), ("Sheaf", "Lucy Gray"), ("Sheaf", "Jessup Diggs"), ("Sheaf", "Coral"), ("Sheaf", "Androcles"),
          ("Sheaf", "Coriolanus")])

# %%
brandy = ([("Brandy", "Tanner"),
("Brandy", "Dill"), ("Brandy", "Reaper Ash"), ("Brandy", "Lucy Gray"), ("Brandy", "Jessup Diggs"), ("Brandy", "Coral"), ("Brandy", "Arachne"),
           ("Brandy", "Coriolanus")])

# %%
tanner = ([("Tanner", "Dill"), ("Tanner", "Reaper Ash"), ("Tanner", "Lucy Gray"), ("Tanner", "Jessup Diggs"), ("Tanner", "Coral"), ("Tanner", "Domitia"),
           ("Tanner", "Coriolanus")])

# %%
dill = ([("Dill", "Reaper Ash"), ("Dill", "Lucy Gray"), ("Dill", "Jessup Diggs"), ("Dill", "Coral"), ("Dill", "Felix"), ("Dill", "Coriolanus")])

# %%
reaper_ash = ([("Reaper Ash", "Lucy Gray"), ("Reaper Ash", "Jessup Diggs"), ("Reaper Ash", "Coral"), ("Reaper Ash", "Clemensia"), ("Reaper Ash", "Coriolanus")])

# %%
lucy_gray = ([("Lucy Gray", "Jessup Diggs"), ("Lucy Gray", "Coral"), ("Lucy Gray", "Billy Taupe"), ("Lucy Gray", "Clerk Clamine"), ("Lucy Gray", "Tam Amber"),
              ("Lucy Gray", "Coriolanus")])

# %%
jessup = ([("Jessup Diggs", "Velvereen"), ("Jessup Diggs", "Sabyn"),("Jessup Diggs", "Marcus"), ("Jessup Diggs", "Teslee"), ("Jessup Diggs", "Circ"), ("Jessup Diggs", "Coral"),
("Jessup Diggs", "Mizzen"), ("Jessup Diggs", "Sol"), ("Jessup Diggs", "Hy"), ("Jessup Diggs", "Ginnee"), ("Jessup Diggs", "Otto"),("Jessup Diggs", "Lamina"), ("Jessup Diggs", "Treach"),
("Jessup Diggs", "Wovey"), ("Jessup Diggs", "Bobbin"), ("Jessup Diggs", "Panlo"), ("Jessup Diggs", "Sheaf"), ("Jessup Diggs", "Brandy"), ("Jessup Diggs", "Tanner"),
("Jessup Diggs", "Dill"), ("Jessup Diggs", "Reaper Ash"), ("Jessup Diggs", "Lucy Gray"), ("Jessup Diggs", "Lysistrata"), ("Jessup Diggs", "Coriolanus")])

# %%
billy_taupe = ([("Billy Taupe", "Lucy Gray"), ("Billy Taupe", "Clerk Clamine"), ("Billy Taupe", "Tam Amber"), ("Billy Taupe", "Coriolanus")])

# %%
clerk_clamine = ([("Clerk Clamine", "Billy Taupe"), ("Clerk Clamine", "Lucy Gray"), ("Clerk Clamine", "Tam Amber"), ("Clerk Clamine", "Coriolanus")])

# %%
tam_amber = ([("Tam Amber", "Lucy Gray"), ("Tam Amber", "Billy Taupe"), ("Tam Amber", "Clerk Clamine"), ("Tam Amber", "Coriolanus")])

# %%
maude = ([("Maude", "Lucy Gray"), ("Maude", "Billy Taupe"), ("Maude", "Clerk Clamine"), ("Maude", "Tam Amber"), ("Maude", "Coriolanus")])

# %%
mayfair  = ([("Mayfair", "Billy Taupe"), ("Mayfair", "Lucy Gray"), ("Mayfair", "Major Lipp"), ("Mayfair", "Coriolanus"), ("Mayfair", "Major Lipp")])

# %%
arlo = ([("Arlo", "Lucy Gray"), ("Arlo", "Mayfair"), ("Arlo", "Lil"), ("Arlo", "Spruce"),("Arlo", "Major Lipp"), ("Arlo", "Coriolanus")])

# %%
lil = ([("Lil", "Arlo"), ("Lil", "Spruce"), ("Lil", "Major Lipp"), ("Lil", "Coriolanus")])

# %%
barb = ([("Barb", "Lucy Gray"), ("Barb", "Billy Taupe"), ("Barb", "Clerk Clamine"), ("Barb", "Tam Amber"), ("Barb", "Maude"), ("Barb", "Coriolanus")])

# %%
coriolanus = ([("Coriolanus", "Lucy Gray"), ("Coriolanus", "Barb"), ("Coriolanus", "Lil"), ("Coriolanus", "Arlo"),
 ("Coriolanus", "Spruce"), ("Coriolanus", "Mayfair"), ("Coriolanus", "Maude"), ("Coriolanus", "Billy Taupe"),
  ("Coriolanus", "Crassus Snow"), ("Coriolanus", "Lady Vó"), ("Coriolanus", "Major Lipp"), ("Coriolanus", "Apollo"),
   ("Coriolanus", "Livia Cardew"), ("Coriolanus", "Palmyra"), ("Coriolanus", "Florus"), ("Coriolanus", "Io Jasper"),
    ("Coriolanus", "Urban Canville"), ("Coriolanus", "Festus"), ("Coriolanus", "Persephone"), ("Coriolanus", "Gaius"),
     ("Coriolanus", "Androcles"), ("Coriolanus", "Domitia"), ("Coriolanus", "Arachne"), ("Coriolanus", "Clemensia"),
               ("Coriolanus", "Felix"), ("Coriolanus", "Lysistrata"), ("Coriolanus", "Dennis"), ("Coriolanus", "Hilarius"),
                ("Coriolanus", "Pliny"), ("Coriolanus", "Volumnia"), ("Coriolanus", "Iphigenia"), ("Coriolanus", "Vipsania"), ("Coriolanus", "Juno"),
               ("Coriolanus", "Ma Plinth"), ("Coriolanus", "Coral"), ("Coriolanus", "Antonius"), ("Coriolanus", "Egeria")])

# %%
egeria = ([("Egeria", "Antonius")])

# %%
tigris = ([("Tigris", "Coriolanus"), ("Tigris", "Crassus Snow"), ("Tigris", "Lady Vó"), ("Tigris", "Lucy Gray"), ("Tigris", "Finnick"), ("Tigris", "Peeta"),
           ("Tigris", "Katniss"), ("Tigris", "Gale"), ("Tigris", "Cressida"), ("Tigris", "Plutarch"), ("Tigris", "Fabricia Whatnot"), ("Tigris", "Pollux")])

# %%
remus = ([("Remus", "Tigris"), ("Remus", "Coriolanus"), ("Remus", "Lady Vó")])

# %%
casca = ([("Casca", "Coriolanus"), ("Casca", "Volumnia"), ("Casca", "Crassus Snow"), ("Casca", "Livia Cardew"),
 ("Casca", "Palmyra"), ("Casca", "Florus"),("Casca", "Io Jasper"), ("Casca", "Urban Canville"), ("Casca", "Festus"),
  ("Casca", "Persephone"), ("Casca", "Dennis"), ("Casca", "Iphigenia"), ("Casca", "Apollo"),
   ("Casca", "Diana"), ("Casca", "Vipsania"), ("Casca", "Pliny"), ("Casca", "Juno"), ("Casca", "Hilarius"), ("Casca", "Gaius"),
    ("Casca", "Androcles"), ("Casca", "Domitia"), ("Casca", "Arachne"), ("Casca", "Clemensia"), ("Casca", "Felix"), ("Casca", "Lysistrata")])

# %%
diana = ([("Diana", "Coriolanus"), ("Diana", "Apollo"),("Diana", "Livia Cardew"), ("Diana", "Palmyra"),
          ("Diana", "Florus"), ("Diana", "Io Jasper"), ("Diana", "Urban Canville"), ("Diana", "Festus"),
           ("Diana", "Persephone"), ("Diana", "Gaius"), ("Diana", "Androcles"), ("Diana", "Domitia"),
            ("Diana", "Arachne"), ("Diana", "Clemensia"), ("Diana", "Felix"), ("Diana", "Lysistrata"), ("Diana", "Vipsania"), ("Diana", "Dennis"),
          ("Diana", "Iphigenia"), ("Diana", "Pliny"), ("Diana", "Hilarius"), ("Diana", "Juno"), ("Diana", "Sejanus")])

# %%
sejanus = ([("Sejanus", "Coriolanus"), ("Sejanus", "Casca"), ("Sejanus", "Major Lipp"), ("Sejanus", "Lucy Gray"), ("Sejanus", "Ma Plinth"), ("Sejanus", "Strabo Plinth"),
            ("Sejanus", "Lucy Gray"), ("Sejanus", "Billy Taupe"), ("Sejanus", "Clerk Clamine"), ("Sejanus", "Tam Amber"), ("Sejanus", "Maude"),
            ("Sejanus", "Apollo"),("Sejanus", "Livia Cardew"), ("Sejanus", "Palmyra"),
          ("Sejanus", "Florus"), ("Sejanus", "Io Jasper"), ("Sejanus", "Urban Canville"), ("Sejanus", "Festus"),
           ("Sejanus", "Persephone"), ("Sejanus", "Gaius"), ("Sejanus", "Androcles"), ("Sejanus", "Domitia"),
            ("Sejanus", "Arachne"), ("Sejanus", "Clemensia"), ("Sejanus", "Felix"), ("Sejanus", "Lysistrata"), ("Sejanus", "Vipsania"), ("Sejanus", "Dennis"),
          ("Sejanus", "Iphigenia"), ("Sejanus", "Pliny"), ("Sejanus", "Hilarius"), ("Sejanus", "Juno",), ("Sejanus", "Spruce"), ("Sejanus", "Lil")
])

# %%
apollo = ([("Apollo", "Livia Cardew"), ("Apollo", "Palmyra"),
          ("Apollo", "Florus"), ("Apollo", "Io Jasper"), ("Apollo", "Urban Canville"), ("Apollo", "Festus"),
           ("Apollo", "Persephone"), ("Apollo", "Gaius"), ("Apollo", "Androcles"), ("Apollo", "Domitia"),
            ("Apollo", "Arachne"), ("Apollo", "Clemensia"), ("Apollo", "Felix"), ("Apollo", "Lysistrata"), ("Apollo", "Vipsania"), ("Apollo", "Dennis"),
          ("Apollo", "Iphigenia"), ("Apollo", "Pliny"), ("Apollo", "Hilarius"), ("Apollo", "Juno")
])

# %%
livia_cardew = ([("Livia Cardew", "Palmyra"),
          ("Livia Cardew", "Florus"), ("Livia Cardew", "Io Jasper"), ("Livia Cardew", "Urban Canville"), ("Livia Cardew", "Festus"),
           ("Livia Cardew", "Persephone"), ("Livia Cardew", "Gaius"), ("Livia Cardew", "Androcles"), ("Livia Cardew", "Domitia"),
            ("Livia Cardew", "Arachne"), ("Livia Cardew", "Clemensia"), ("Livia Cardew", "Felix"), ("Livia Cardew", "Lysistrata"), ("Livia Cardew", "Vipsania"), ("Livia Cardew", "Dennis"),
          ("Livia Cardew", "Iphigenia"), ("Livia Cardew", "Pliny"), ("Livia Cardew", "Hilarius"), ("Livia Cardew", "Juno"), ("Livia Cardew", "Fulvia Cardew")
])

# %%
palmyra = ([("Palmyra", "Florus"), ("Palmyra", "Io Jasper"), ("Palmyra", "Urban Canville"), ("Palmyra", "Festus"),
           ("Palmyra", "Persephone"), ("Palmyra", "Gaius"), ("Palmyra", "Androcles"), ("Palmyra", "Domitia"),
            ("Palmyra", "Arachne"), ("Palmyra", "Clemensia"), ("Palmyra", "Felix"), ("Palmyra", "Lysistrata"), ("Palmyra", "Vipsania"), ("Palmyra", "Dennis"),
          ("Palmyra", "Iphigenia"), ("Palmyra", "Pliny"), ("Palmyra", "Hilarius"), ("Palmyra", "Juno")
])

# %%
florus = ([("Florus", "Io Jasper"), ("Florus", "Urban Canville"), ("Florus", "Festus"),
           ("Florus", "Persephone"), ("Florus", "Gaius"), ("Florus", "Androcles"), ("Florus", "Domitia"),
            ("Florus", "Arachne"), ("Florus", "Clemensia"), ("Florus", "Felix"), ("Florus", "Lysistrata"), ("Florus", "Vipsania"), ("Florus", "Dennis"),
          ("Florus", "Iphigenia"), ("Florus", "Pliny"), ("Florus", "Hilarius"), ("Florus", "Juno")
])

# %%
io_jasper = ([("Io Jasper", "Urban Canville"), ("Io Jasper", "Festus"),
           ("Io Jasper", "Persephone"), ("Io Jasper", "Gaius"), ("Io Jasper", "Androcles"), ("Io Jasper", "Domitia"),
            ("Io Jasper", "Arachne"), ("Io Jasper", "Clemensia"), ("Io Jasper", "Felix"), ("Io Jasper", "Lysistrata"), ("Io Jasper", "Vipsania"), ("Io Jasper", "Dennis"),
          ("Io Jasper", "Iphigenia"), ("Io Jasper", "Pliny"), ("Io Jasper", "Hilarius"), ("Io Jasper", "Juno")
])

# %%
urban = ([("Urban Canville", "Festus"),
           ("Urban Canville", "Persephone"), ("Urban Canville", "Gaius"), ("Urban Canville", "Androcles"), ("Urban Canville", "Domitia"),
            ("Urban Canville", "Arachne"), ("Urban Canville", "Clemensia"), ("Urban Canville", "Felix"), ("Urban Canville", "Lysistrata"), ("Urban Canville", "Vipsania"), ("Urban Canville", "Dennis"),
          ("Urban Canville", "Iphigenia"), ("Urban Canville", "Pliny"), ("Urban Canville", "Hilarius"), ("Urban Canville", "Juno")
])

# %%
festus = ([("Festus", "Persephone"), ("Festus", "Gaius"), ("Festus", "Androcles"), ("Festus", "Domitia"),
            ("Festus", "Arachne"), ("Festus", "Clemensia"), ("Festus", "Felix"), ("Festus", "Lysistrata"), ("Festus", "Vipsania"), ("Festus", "Dennis"),
          ("Festus", "Iphigenia"), ("Festus", "Pliny"), ("Festus", "Hilarius"), ("Festus", "Juno"), ("Festus", "Coral")
])

# %%
persephone = ([("Persephone", "Gaius"), ("Persephone", "Androcles"), ("Persephone", "Domitia"),
            ("Persephone", "Arachne"), ("Persephone", "Clemensia"), ("Persephone", "Felix"), ("Persephone", "Lysistrata"), ("Persephone", "Vipsania"), ("Persephone", "Dennis"),
          ("Persephone", "Iphigenia"), ("Persephone", "Pliny"), ("Persephone", "Hilarius"), ("Persephone", "Juno")
])

# %%
gaius = ([("Gaius", "Androcles"), ("Gaius", "Domitia"),
            ("Gaius", "Arachne"), ("Gaius", "Clemensia"), ("Gaius", "Felix"), ("Gaius", "Lysistrata"), ("Gaius", "Vipsania"), ("Gaius", "Dennis"),
          ("Gaius", "Iphigenia"), ("Gaius", "Pliny"), ("Gaius", "Hilarius"), ("Gaius", "Juno")
])

# %%
androcles = ([("Androcles", "Domitia"),
            ("Androcles", "Arachne"), ("Androcles", "Clemensia"), ("Androcles", "Felix"), ("Androcles", "Lysistrata"), ("Androcles", "Vipsania"), ("Androcles", "Dennis"),
          ("Androcles", "Iphigenia"), ("Androcles", "Pliny"), ("Androcles", "Hilarius"), ("Androcles", "Juno")
])

# %%
domitia = ([("Domitia", "Arachne"), ("Domitia", "Clemensia"), ("Domitia", "Felix"), ("Domitia", "Lysistrata"), ("Domitia", "Vipsania"), ("Domitia", "Dennis"),
          ("Domitia", "Iphigenia"), ("Domitia", "Pliny"), ("Domitia", "Hilarius"), ("Domitia", "Juno")
])

# %%
arachne = ([("Arachne", "Clemensia"), ("Arachne", "Felix"), ("Arachne", "Lysistrata"), ("Arachne", "Vipsania"), ("Arachne", "Dennis"),
          ("Arachne", "Iphigenia"), ("Arachne", "Pliny"), ("Arachne", "Hilarius"), ("Arachne", "Juno")
])

# %%
clemensia = ([("Clemensia", "Felix"), ("Clemensia", "Lysistrata"), ("Clemensia", "Vipsania"), ("Clemensia", "Dennis"),
          ("Clemensia", "Iphigenia"), ("Clemensia", "Pliny"), ("Clemensia", "Hilarius"), ("Clemensia", "Juno")
])

# %%
felix = ([("Felix", "Lysistrata"), ("Felix", "Vipsania"), ("Felix", "Dennis"),
          ("Felix", "Iphigenia"), ("Felix", "Pliny"), ("Felix", "Hilarius"), ("Felix", "Juno")
])

# %%
lysistrata = ([("Lysistrata", "Vipsania"), ("Lysistrata", "Dennis"),
          ("Lysistrata", "Iphigenia"), ("Lysistrata", "Pliny"), ("Lysistrata", "Hilarius"), ("Lysistrata", "Juno")
])

# %%
vipsania = ([("Vipsania", "Dennis"),
          ("Vipsania", "Iphigenia"), ("Vipsania", "Pliny"), ("Vipsania", "Hilarius"), ("Vipsania", "Juno")
])

# %%
dennis = ([("Dennis", "Iphigenia"), ("Dennis", "Pliny"), ("Dennis", "Hilarius"), ("Dennis", "Juno")
])

# %%
iphigenia = ([("Iphigenia", "Pliny"), ("Iphigenia", "Hilarius"), ("Iphigenia", "Juno")
])

# %%
pliny = ([("Pliny", "Hilarius"), ("Pliny", "Juno")
])

# %%
hilarius = ([("Hilarius", "Juno"), ("Hilarius", "Trajan")])

# %%
strabo = ([("Strabo Plinth", "Coriolanus"), ("Strabo Plinth", "Ma Plinth"), ("Strabo Plinth", "Volumnia")])

# %%
crassus = ([("Crassus Snow", "Lady Vó")])

# %%
seneca = ([("Seneca", "Coriolanus"), ("Seneca", "Arachne"), ("Seneca", "Lucia")])

# %%
primrose = ([("Primrose", "Katniss"), ("Primrose", "Gale"), ("Primrose", "Peeta")])

# %%
sra_everdeen = ([("Sra Everdeen", "Katniss"), ("Sra Everdeen", "Gale"), ("Sra Everdeen", "Peeta"), ("Sra Everdeen", "Primrose"), ("Sra Everdeen", "Maysilee"),
                 ("Sra Everdeen", "Coriolanus"), ("Sra Everdeen", "Haymitch"), ("Sra Everdeen", "Sr Mellark")])

# %%
sr_mellark = ([("Sr Mellark", "Peeta"), ("Sr Mellark", "Katniss"), ("Sr Mellark", "Gale"), ("Sr Mellark", "Primrose")])

# %%
madge = ([("Madge", "Katniss"), ("Madge", "Maysilee"), ("Madge", "Gale"), ("Madge", "Peeta")])

# %%
katniss = ([("Katniss", "Peeta"), ("Katniss", "Primrose"), ("Katniss", "Coriolanus"), ("Katniss", "Gale"), ("Katniss", "Finnick"), ("Katniss", "Cinna"), ("Katniss", "Caesar"),
            ("Katniss", "Tigris"),("Katniss", "Flavius"), ("Katniss", "Octavia"), ("Katniss", "Venia"), ("Katniss", "Johanna"), ("Katniss", "Marvel"), ("Katniss", "Glimmer"),
            ("Katniss", "Cato"), ("Katniss", "Clove"), ("Katniss", "Beetee"), ("Katniss", "Wiress"), ("Katniss", "Annie"), ("Katniss", "Marina"), ("Katniss", "Mags"),
            ("Katniss", "Foxface"), ("Katniss", "Jason"), ("Katniss", "Blight"), ("Katniss", "Demetria"), ("Katniss", "Woof"), ("Katniss", "Cecelia"), ("Katniss", "Bonnie"),
            ("Katniss", "Twill"), ("Katniss", "Chaff"), ("Katniss", "Seeder"), ("Katniss", "Alma"), ("Katniss", "Boggs"), ("Katniss", "Morphling#1"),
            ("Katniss", "Morphling#2"), ("Katniss", "Cashmere"), ("Katniss", "Gloss"), ("Katniss", "Enobaria"), ("Katniss", "Brutus")])

# %%
peeta = ([("Peeta", "Portia"), ("Peeta", "Johanna"), ("Peeta", "Gale"), ("Peeta", "Marvel"), ("Peeta", "Glimmer"),
            ("Peeta", "Cato"), ("Peeta", "Clove"), ("Peeta", "Beetee"), ("Peeta", "Wiress"), ("Peeta", "Annie"), ("Peeta", "Marina"), ("Peeta", "Mags"),
            ("Peeta", "Foxface"), ("Peeta", "Jason"), ("Peeta", "Blight"), ("Peeta", "Demetria"), ("Peeta", "Woof"), ("Peeta", "Cecelia"), ("Peeta", "Chaff"), ("Peeta", "Seeder"), ("Peeta", "Alma"), ("Peeta", "Boggs"), ("Peeta", "Morphling#1"),
            ("Peeta", "Morphling#2"), ("Peeta", "Cashmere"), ("Peeta", "Gloss"), ("Peeta", "Enobaria"), ("Peeta", "Brutus")

])

# %%
rue = ([("Rue", "Katniss"), ("Rue", "Thresh"), ("Rue", "Caesar"), ("Rue", "Cato"), ("Rue", "Clove"), ("Rue", "Foxface"), ("Rue", "Jason"), ("Rue", "Demetria"),
        ("Rue", "Glimmer"), ("Rue", "Marvel"), ("Rue", "Peeta"), ("Rue", "Marina")])

# %%
marvel = ([("Marvel", "Glimmer"), ("Marvel", "Rue"), ("Marvel", "Katniss"), ("Marvel", "Cato"), ("Marvel", "Clove"), ("Marvel", "Foxface"), ("Marvel", "Jason"),
           ("Marvel", "Demetria"), ("Marvel", "Peeta"), ("Marvel", "Thresh"), ("Marvel", "Marina")])

# %%
glimmer = ([("Glimmer", "Cato"), ("Glimmer", "Clove"), ("Glimmer", "Foxface"), ("Glimmer", "Jason"), ("Glimmer", "Demetria"), ("Glimmer", "Thresh"), ("Glimmer", "Marina")])

# %%
cato = ([("Cato", "Clove"), ("Cato", "Foxface"), ("Cato", "Jason"), ("Cato", "Demetria"), ("Cato", "Thresh"), ("Cato", "Marina")])

# %%
clove = ([("Clove", "Foxface"), ("Clove", "Jason"), ("Clove", "Demetria"), ("Clove", "Thresh"), ("Clove", "Marina")])

# %%
foxface = ([("Foxface", "Jason"), ("Foxface", "Demetria"), ("Foxface", "Thresh"), ("Foxface", "Marina")])

# %%
jason = ([("Jason", "Demetria"), ("Jason", "Thresh"), ("Jason", "Marina")])

# %%
thresh = ([("Thresh", "Marina"), ("Thresh", "Katniss")])

# %%
flickerman = ([("Caesar", "Lucretius"), ("Caesar", "Claudius"), ("Caesar", "Katniss"), ("Caesar", "Peeta"), ("Caesar", "Glimmer"), ("Caesar", "Marvel"),
               ("Caesar", "Clove"), ("Caesar", "Cato"), ("Caesar", "Foxface"), ("Caesar", "Rue"), ("Caesar", "Jason"), ("Caesar", "Demetria"),
               ("Caesar", "Thresh"), ("Caesar", "Cashmere"), ("Caesar", "Gloss"), ("Caesar", "Enobaria"), ("Caesar", "Brutus"), ("Caesar", "Beetee"),
               ("Caesar", "Wiress"), ("Caesar", "Mags"), ("Caesar", "Finnick"), ("Caesar", "Morphling#1"), ("Caesar", "Morphling#2"),
               ("Caesar", "Johanna"), ("Caesar", "Blight"), ("Caesar", "Cecelia"), ("Caesar", "Woof"), ("Caesar", "Seeder"), ("Caesar", "Chaff"),
               ("Caesar", "Coriolanus")])

# %%
haymitch = ([("Haymitch", "Maysilee"), ("Haymitch", "Katniss"), ("Haymitch", "Peeta"), ("Haymitch", "Effie")])

# %%
effie = ([("Effie", "Katniss"), ("Effie", "Peeta")])

# %%
finnick = ([("Finnick", "Peeta"), ("Finnick", "Haymitch"), ("Finnick", "Mags"), ("Finnick", "Annie"), ("Finnick", "Dalton"), ("Finnick", "Tigris")])

# %%
cashmere = ([("Cashmere", "Gloss"), ("Cashmere", "Enobaria"), ("Cashmere", "Brutus"), ("Cashmere", "Beetee"), ("Cashmere", "Wiress"), ("Cashmere", "Mags"),
             ("Cashmere", "Morphling#1"), ("Cashmere", "Morphling#2"), ("Cashmere", "Johanna"), ("Cashmere", "Blight"), ("Cashmere", "Cecelia"),
             ("Cashmere", "Woof"),("Cashmere", "Seeder"), ("Cashmere", "Chaff"), ("Cashmere", "Katniss"), ("Cashmere",  "Peeta"), ("Cashmere", "Finnick")])

# %%
gloss = ([("Gloss", "Enobaria"), ("Gloss", "Brutus"), ("Gloss", "Beetee"), ("Gloss", "Wiress"), ("Gloss", "Mags"),
             ("Gloss", "Morphling#1"), ("Gloss", "Morphling#2"), ("Gloss", "Johanna"), ("Gloss", "Blight"), ("Gloss", "Cecelia"),
             ("Gloss", "Woof"),("Gloss", "Seeder"), ("Gloss", "Chaff"), ("Gloss", "Katniss"), ("Gloss",  "Peeta"), ("Gloss", "Finnick")])

# %%
enobaria = ([("Enobaria", "Brutus"), ("Enobaria", "Beetee"), ("Enobaria", "Wiress"), ("Enobaria", "Mags"),
             ("Enobaria", "Morphling#1"), ("Enobaria", "Morphling#2"), ("Enobaria", "Johanna"), ("Enobaria", "Blight"), ("Enobaria", "Cecelia"),
             ("Enobaria", "Woof"),("Enobaria", "Seeder"), ("Enobaria", "Chaff"), ("Enobaria", "Katniss"), ("Enobaria", "Peeta"), ("Enobaria", "Finnick")])

# %%
brutus = ([("Brutus", "Beetee"), ("Brutus", "Wiress"), ("Brutus", "Mags"),
             ("Brutus", "Morphling#1"), ("Brutus", "Morphling#2"), ("Brutus", "Johanna"), ("Brutus", "Blight"), ("Brutus", "Cecelia"),
             ("Brutus", "Woof"),("Brutus", "Seeder"), ("Brutus", "Chaff"), ("Brutus", "Katniss"), ("Brutus", "Peeta"), ("Brutus", "Finnick")])

# %%
beetee = ([("Beetee", "Wiress"), ("Beetee", "Mags"),
             ("Beetee", "Morphling#1"), ("Beetee", "Morphling#2"), ("Beetee", "Johanna"), ("Beetee", "Blight"), ("Beetee", "Cecelia"),
             ("Beetee", "Woof"),("Beetee", "Seeder"), ("Beetee", "Chaff"), ("Beetee", "Katniss"), ("Beetee", "Peeta"), ("Beetee", "Finnick")])

# %%
wiress = ([("Wiress", "Mags"),
             ("Wiress", "Morphling#1"), ("Wiress", "Morphling#2"), ("Wiress", "Johanna"), ("Wiress", "Blight"), ("Wiress", "Cecelia"),
             ("Wiress", "Woof"),("Wiress", "Seeder"), ("Wiress", "Chaff"), ("Wiress", "Katniss"), ("Wiress", "Peeta"), ("Wiress", "Finnick")])

# %%
mags = ([    ("Mags", "Morphling#1"), ("Mags", "Morphling#2"), ("Mags", "Johanna"), ("Mags", "Blight"), ("Mags", "Cecelia"),
             ("Mags", "Woof"),("Mags", "Seeder"), ("Mags", "Chaff"), ("Mags", "Katniss"), ("Mags", "Peeta"), ("Mags", "Finnick")])

# %%
morphling_1 = ([("Morphling#1", "Morphling#2"), ("Morphling#1", "Johanna"), ("Morphling#1", "Blight"), ("Morphling#1", "Cecelia"),
             ("Morphling#1", "Woof"),("Morphling#1", "Seeder"), ("Morphling#1", "Chaff"), ("Morphling#1", "Katniss"), ("Morphling#1", "Peeta"),
                ("Morphling#1", "Finnick")])

# %%
morphling_2 = ([("Morphling#2", "Johanna"), ("Morphling#2", "Blight"), ("Morphling#2", "Cecelia"),
             ("Morphling#2", "Woof"),("Morphling#2", "Seeder"), ("Morphling#2", "Chaff"), ("Morphling#2", "Katniss"), ("Morphling#2", "Peeta"),
                ("Morphling#2", "Finnick")])

# %%
johanna = ([("Johanna", "Blight"), ("Johanna", "Cecelia"),
             ("Johanna", "Woof"),("Johanna", "Seeder"), ("Johanna", "Chaff"), ("Johanna", "Katniss"), ("Johanna", "Peeta"), ("Johanna", "Finnick")])

# %%
blight = ([("Blight", "Cecelia"),
             ("Blight", "Woof"),("Blight", "Seeder"), ("Blight", "Chaff"), ("Blight", "Katniss"), ("Blight", "Peeta"), ("Blight", "Finnick")])

# %%
cecelia = ([("Cecelia", "Woof"),
             ("Cecelia", "Seeder"), ("Cecelia", "Chaff"), ("Cecelia", "Katniss"), ("Cecelia", "Peeta"), ("Cecelia", "Finnick")])

# %%
woof = ([("Woof", "Seeder"), ("Woof", "Chaff"), ("Woof", "Katniss"), ("Woof", "Peeta"), ("Woof", "Finnick")])

# %%
seeder = ([("Seeder", "Chaff"), ("Seeder", "Katniss"), ("Seeder", "Peeta"), ("Seeder", "Finnick")])

# %%
chaff = ([("Chaff", "Katniss"), ("Chaff", "Peeta"), ("Chaff", "Finnick")])

# %%
dalton = ([("Dalton", "Annie")])

# %%
annie = ([("Annie", "Katniss"), ("Annie", "Gale"), ("Annie", "Johanna"), ("Annie", "Beetee"), ("Annie", "Delly"), ("Annie", "Mags"), ("Annie", "Peeta")])

# %%
delly = ([("Delly", "Beetee"), ("Delly", "Katniss"), ("Delly", "Peeta"), ("Delly", "Gale"), ("Delly", "Johanna"), ("Delly", "Annie"), ("Delly", "Finnick")])

# %%
lyme = ([("Lyme", "Alma"), ("Lyme", "Katniss"), ("Lyme", "Peeta"), ("Lyme", "Beetee"), ("Lyme", "Gale"), ("Lyme", "Paylor")])

# %%
alma = ([("Alma", "Coriolanus"), ("Alma", "Plutarch"), ("Alma", "Paylor"), ("Alma", "Cressida")])

# %%
plutarch = ([("Plutarch", "Coriolanus"), ("Plutarch", "Haymitch"), ("Plutarch", "Fulvia Cardew"), ("Plutarch", "Katniss"), ("Plutarch", "Peeta"), ("Plutarch", "Seneca"),
             ("Plutarch", "Finnick"), ("Plutarch", "Beetee"), ("Plutarch", "Gale"), ("Plutarch", "Paylor"), ("Plutarch", "Hilarius"), ("Plutarch", "Trajan")])

# %%
paylor = ([("Paylor", "Katniss"), ("Paylor", "Gale"), ("Paylor", "Cressida"), ("Paylor", "Pollux"), ("Paylor", "Castor"), ("Paylor", "Messala"), ("Paylor", "Lyme")])

# %%
presidente_ravinstill = ([("Presidente Ravinstill", "Volumnia"), ("Presidente Ravinstill", "Felix"), ("Presidente Ravinstill", "Coriolanus")])

# %%
cressida = ([("Cressida", "Pollux"), ("Cressida", "Castor"), ("Cressida", "Messala"), ("Cressida", "Katniss"), ("Cressida", "Finnick"), ("Cressida", "Gale"),
             ("Cressida", "Fulvia Cardew"), ("Cressida", "Peeta"), ("Cressida", "Jackson"), ("Cressida", "Homes"), ("Cressida", "Mitchell"),
             ("Cressida", "Leeg 1"), ("Cressida", "Leeg 2")])

# %%
pollux = ([("Pollux", "Castor"), ("Pollux", "Messala"), ("Pollux", "Katniss"), ("Pollux", "Finnick"), ("Pollux", "Gale"),
             ("Pollux", "Fulvia Cardew"), ("Pollux", "Peeta"), ("Pollux", "Jackson"), ("Pollux", "Homes"), ("Pollux", "Mitchell"),
             ("Pollux", "Leeg 1"), ("Pollux", "Leeg 2")])

# %%
castor = ([("Castor", "Messala"), ("Castor", "Katniss"), ("Castor", "Finnick"), ("Castor", "Gale"),
             ("Castor", "Fulvia Cardew"), ("Castor", "Peeta"), ("Castor", "Jackson"), ("Castor", "Homes"), ("Castor", "Mitchell"),
             ("Castor", "Leeg 1"), ("Castor", "Leeg 2")])

# %%
jackson = ([("Jackson", "Katniss"), ("Jackson", "Finnick"), ("Jackson", "Gale"),
             ("Jackson", "Fulvia Cardew"), ("Jackson", "Peeta"), ("Jackson", "Homes"), ("Jackson", "Mitchell"),
             ("Jackson", "Leeg 1"), ("Jackson", "Leeg 2")])

# %%
homes = ([("Homes", "Katniss"), ("Homes", "Finnick"), ("Homes", "Gale"),
             ("Homes", "Fulvia Cardew"), ("Homes", "Peeta"), ("Homes", "Mitchell"),
             ("Homes", "Leeg 1"), ("Homes", "Leeg 2")])

# %%
mitchell = ([("Mitchell", "Katniss"), ("Mitchell", "Finnick"), ("Mitchell", "Gale"),
             ("Mitchell", "Fulvia Cardew"), ("Mitchell", "Peeta"), ("Mitchell", "Leeg 1"), ("Mitchell", "Leeg 2")])

# %%
leeg_1 = ([("Leeg 1", "Katniss"), ("Leeg 1", "Finnick"), ("Leeg 1", "Gale"),
             ("Leeg 1", "Fulvia Cardew"), ("Leeg 1", "Peeta"), ("Leeg 1", "Leeg 2")])

# %%
leeg_2 = ([("Leeg 2", "Katniss"), ("Leeg 2", "Finnick"), ("Leeg 2", "Gale"),
             ("Leeg 2", "Fulvia Cardew")])

# %%
messala = ([("Messala", "Katniss"), ("Messala", "Finnick"), ("Messala", "Gale"),
             ("Messala", "Fulvia Cardew"), ("Messala", "Peeta"), ("Messala", "Jackson"), ("Messala", "Homes"), ("Messala", "Mitchell"),
             ("Messala", "Leeg 1"), ("Messala", "Leeg 2")])

# %%
cray = ([("Cray", "Gale"), ("Cray", "Katniss"), ("Cray", "Haymitch")])

# %%
darius = ([("Darius", "Gale"), ("Darius", "Katniss"), ("Darius", "Haymitch"), ("Darius", "Peeta"), ("Darius", "Effie")])

# %%
romulus = ([("Romulus", "Gale"), ("Romulus", "Katniss"), ("Romulus", "Darius"), ("Romulus", "Peeta"), ("Romulus", "Haymitch")])

# %%
lavinia = ([("Lavinia", "Katniss"), ("Lavinia", "Peeta"), ("Lavinia", "Haymitch"), ("Lavinia", "Effie")])

# %%
greasy_sae = ([("Greasy Sae", "Katniss"), ("Greasy Sae", "Gale")])

# %%
purnia = ([("Purnia", "Romulus"), ("Purnia", "Darius"), ("Purnia", "Gale"), ("Purnia", "Katniss")])

# %%
bristel = ([("Bristel", "Haymitch"), ("Bristel", "Gale"), ("Bristel", "Thorn"), ("Bristel", "Romulus")])

# %%
thorn = ([("Thorn", "Bristel"), ("Thorn", "Gale"), ("Thorn", "Romulus"), ("Thorn", "Haymitch")])

# %%
hazelle = ([("Hazelle", "Gale"), ("Hazelle", "Katniss"), ("Hazelle", "Rory"), ("Hazelle", "Vick"), ("Hazelle", "Posy"), ("Hazelle", "Haymitch")])

# %%
gale = ([("Gale", "Rory"), ("Gale", "Vick"), ("Gale", "Posy")])

# %%
rory = ([("Rory", "Vick"), ("Rory", "Posy")])

# %%
vick = ([("Vick", "Posy")])

# %%
octavia = ([("Octavia", "Venia"), ("Octavia", "Posy"), ("Octavia", "Flavius")])

# %%
venia = ([("Venia", "Flavius")])

# %%
major_lipp = ([("Major Lipp", "Spruce")])

# %%
hoff = ([("Comandante Hoff", "Coriolanus"), ("Comandante Hoff", "Major Lipp"), ("Comandante Hoff", "Spruce"), ("Comandante Hoff", "Sejanus"),
         ("Comandante Hoff", "Arlo")])

# %%
boggs = ([("Boggs", "Jackson"), ("Boggs", "Homes"), ("Boggs", "Mitchell"), ("Boggs", "Leeg 1"), ("Boggs", "Leeg 2"), ("Boggs", "Finnick"), ("Boggs", "Katniss"),
              ("Boggs", "Gale"), ("Boggs", "Peeta"), ("Boggs", "Cressida"), ("Boggs", "Messala"), ("Boggs", "Pollux"), ("Boggs", "Castor")])

# %%
lista = annie + delly + sra_everdeen + sr_mellark + major_lipp + hoff + venia + octavia + hazelle + gale + rory + vick + purnia + bristel + thorn + greasy_sae + cray + darius + romulus + lavinia + boggs + messala + leeg_1 + leeg_2 + mitchell + homes + jackson + castor + pollux + cressida + boggs + paylor + presidente_ravinstill + plutarch + alma + thresh + jason + foxface + clove + cato + glimmer + marvel + rue + lyme + dalton + peeta + finnick + effie +  haymitch + flickerman + katniss + primrose + madge + seneca + hilarius + pliny + iphigenia + dennis + apollo + livia_cardew + vipsania + lysistrata + felix + clemensia + arachne + domitia + androcles + gaius + persephone + florus + palmyra + festus + urban + io_jasper + crassus + strabo + sejanus + diana + casca + remus + tigris + coriolanus + barb + arlo + lil + maude + mayfair + tam_amber + clerk_clamine + billy_taupe + facet + valvereen + sabyn + marcus + teslee + circ + mizzen + sol + hy + ginnee + otto + lamina + treach + wovey + bobbin + panlo + sheaf + brandy + tanner + dill + reaper_ash + lucy_gray + jessup + cashmere + gloss + enobaria + brutus + beetee + wiress + mags + morphling_1 + morphling_2 + johanna + blight + cecelia + woof + seeder + chaff

# %%
g = nx.Graph(lista)

# %%
g.size()
# Out:
# 1175

# %%
g.order()
# Out:
# 150

# %%
nx.degree(g)
# Out:
# DegreeView({'Annie': 9, 'Katniss': 66, 'Gale': 33, 'Johanna': 20, 'Beetee': 22, 'Delly': 7, 'Mags': 19, 'Peeta': 53, 'Finnick': 34, 'Sra Everdeen': 8, 'Primrose': 5, 'Maysilee': 3, 'Coriolanus': 75, 'Haymitch': 14, 'Sr Mellark': 5, 'Major Lipp': 7, 'Spruce': 6, 'Comandante Hoff': 5, 'Sejanus': 36, 'Arlo': 7, 'Venia': 3, 'Flavius': 3, 'Octavia': 4, 'Posy': 5, 'Hazelle': 6, 'Rory': 4, 'Vick': 4, 'Purnia': 4, 'Romulus': 8, 'Darius': 7, 'Bristel': 4, 'Thorn': 4, 'Greasy Sae': 2, 'Cray': 3, 'Effie': 5, 'Lavinia': 4, 'Boggs': 13, 'Jackson': 14, 'Homes': 14, 'Mitchell': 14, 'Leeg 1': 14, 'Leeg 2': 13, 'Cressida': 17, 'Messala': 15, 'Pollux': 16, 'Castor': 15, 'Fulvia Cardew': 11, 'Paylor': 9, 'Lyme': 6, 'Presidente Ravinstill': 3, 'Volumnia': 4, 'Felix': 26, 'Plutarch': 14, 'Seneca': 4, 'Hilarius': 27, 'Trajan': 2, 'Alma': 7, 'Thresh': 10, 'Marina': 10, 'Jason': 12, 'Demetria': 10, 'Foxface': 12, 'Clove': 12, 'Cato': 12, 'Glimmer': 12, 'Marvel': 12, 'Rue': 12, 'Caesar': 30, 'Dalton': 2, 'Po
# ...

# %%
sorted(nx.degree(g), key=lambda x: x[1], reverse=True)
# Out:
# [('Coriolanus', 75),
#  ('Katniss', 66),
#  ('Peeta', 53),
#  ('Sejanus', 36),
#  ('Finnick', 34),
#  ('Gale', 33),
#  ('Lucy Gray', 33),
#  ('Caesar', 30),
#  ('Hilarius', 27),
#  ('Felix', 26),
#  ('Arachne', 26),
#  ('Livia Cardew', 26),
#  ('Casca', 26),
#  ('Juno', 25),
#  ('Pliny', 25),
#  ('Iphigenia', 25),
#  ('Dennis', 25),
#  ('Apollo', 25),
#  ('Palmyra', 25),
#  ('Florus', 25),
#  ('Io Jasper', 25),
#  ('Urban Canville', 25),
#  ('Festus', 25),
#  ('Persephone', 25),
#  ('Gaius', 25),
#  ('Androcles', 25),
#  ('Domitia', 25),
#  ('Clemensia', 25),
#  ('Lysistrata', 25),
#  ('Vipsania', 25),
#  ('Coral', 25),
#  ('Diana', 25),
#  ('Facet', 25),
#  ('Velvereen', 25),
#  ('Sabyn', 25),
#  ('Marcus', 25),
#  ('Teslee', 25),
#  ('Circ', 25),
#  ('Mizzen', 25),
#  ('Sol', 25),
#  ('Hy', 25),
#  ('Ginnee', 25),
#  ('Otto', 25),
#  ('Lamina', 25),
#  ('Treach', 25),
#  ('Wovey', 25),
#  ('Bobbin', 25),
#  ('Panlo', 25),
#  ('Sheaf', 25),
#  ('Brandy', 25),
#  ('Tanner', 25),
# ...

# %%
sns.histplot(nx.degree(g), bins= 30, color='purple')
plt.legend()
plt.title("Degree Histogram")
plt.xlabel("Degree")
plt.ylabel("Number of Nodes")
# Out:
# /tmp/ipykernel_11968/2002302799.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0, 0.5, 'Number of Nodes')

# %%
node_sizes = [2.3*degree for node, degree in nx.degree(g)]

# %%
nx.draw_kamada_kawai(g, width = 0.5, alpha = 1, with_labels=True, node_color=range(150),style = 'solid', linewidths = 4,
font_color='black', edge_color='#c2c2c2', node_size = node_sizes, font_size = 8, cmap=plt.cm.inferno)

# %%
sorted(nx.degree_centrality(g).items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Coriolanus', 0.5033557046979865),
#  ('Katniss', 0.44295302013422816),
#  ('Peeta', 0.35570469798657717),
#  ('Sejanus', 0.24161073825503354),
#  ('Finnick', 0.22818791946308725),
#  ('Gale', 0.22147651006711408),
#  ('Lucy Gray', 0.22147651006711408),
#  ('Caesar', 0.20134228187919462),
#  ('Hilarius', 0.18120805369127516),
#  ('Felix', 0.174496644295302),
#  ('Arachne', 0.174496644295302),
#  ('Livia Cardew', 0.174496644295302),
#  ('Casca', 0.174496644295302),
#  ('Juno', 0.16778523489932887),
#  ('Pliny', 0.16778523489932887),
#  ('Iphigenia', 0.16778523489932887),
#  ('Dennis', 0.16778523489932887),
#  ('Apollo', 0.16778523489932887),
#  ('Palmyra', 0.16778523489932887),
#  ('Florus', 0.16778523489932887),
#  ('Io Jasper', 0.16778523489932887),
#  ('Urban Canville', 0.16778523489932887),
#  ('Festus', 0.16778523489932887),
#  ('Persephone', 0.16778523489932887),
#  ('Gaius', 0.16778523489932887),
#  ('Androcles', 0.16778523489932887),
#  ('Domitia', 0.16778523489932887),
# ...

# %%
sns.histplot(nx.degree_centrality(g).values(), bins=30, color='red')
plt.legend()
plt.title("Degree Centrality Histogram")
plt.xlabel("Degree Centrality")
plt.ylabel("Number of Nodes")
# Out:
# /tmp/ipykernel_11968/2034647995.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0, 0.5, 'Number of Nodes')

# %%
sorted(nx.betweenness_centrality(g, normalized= False).items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Coriolanus', 5941.983731219767),
#  ('Katniss', 4156.02540129618),
#  ('Caesar', 1180.6724206349236),
#  ('Peeta', 734.4387865359053),
#  ('Gale', 648.7693807858925),
#  ('Tigris', 552.1413973883004),
#  ('Plutarch', 517.2599083139146),
#  ('Finnick', 271.5862554112556),
#  ('Sra Everdeen', 268.6861323317204),
#  ('Lucy Gray', 186.01046176046162),
#  ('Sejanus', 160.6261904761905),
#  ('Livia Cardew', 154.825),
#  ('Seneca', 150.4035714285714),
#  ('Haymitch', 147.57183251689872),
#  ('Hilarius', 130.87096277905107),
#  ('Fulvia Cardew', 119.02878363466607),
#  ('Alma', 89.80697613197617),
#  ('Hazelle', 69.9660708142908),
#  ('Romulus', 39.257503607503715),
#  ('Annie', 37.41453634085223),
#  ('Arachne', 31.916666666666682),
#  ('Beetee', 30.698157979407984),
#  ('Casca', 24.25),
#  ('Cressida', 23.660003347832994),
#  ('Octavia', 21.285264632168726),
#  ('Felix', 20.74999999999999),
#  ('Madge', 19.02283549783548),
#  ('Pollux', 18.640443853273478),
# ...

# %%
sns.histplot(nx.betweenness_centrality(g, normalized= False).values(), bins= 20)
plt.legend()
plt.title("Betweenness Centrality Histogram")
plt.xlabel("Betweenness Centrality")
plt.ylabel("Number of Nodes")
# Out:
# /tmp/ipykernel_11968/3556073899.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0, 0.5, 'Number of Nodes')

# %%
nx.eccentricity(g)
# Out:
# {'Annie': 4,
#  'Katniss': 3,
#  'Gale': 3,
#  'Johanna': 4,
#  'Beetee': 3,
#  'Delly': 4,
#  'Mags': 4,
#  'Peeta': 3,
#  'Finnick': 3,
#  'Sra Everdeen': 3,
#  'Primrose': 4,
#  'Maysilee': 4,
#  'Coriolanus': 3,
#  'Haymitch': 3,
#  'Sr Mellark': 4,
#  'Major Lipp': 4,
#  'Spruce': 4,
#  'Comandante Hoff': 4,
#  'Sejanus': 4,
#  'Arlo': 4,
#  'Venia': 4,
#  'Flavius': 4,
#  'Octavia': 4,
#  'Posy': 4,
#  'Hazelle': 4,
#  'Rory': 4,
#  'Vick': 4,
#  'Purnia': 4,
#  'Romulus': 4,
#  'Darius': 4,
#  'Bristel': 4,
#  'Thorn': 4,
#  'Greasy Sae': 4,
#  'Cray': 4,
#  'Effie': 4,
#  'Lavinia': 4,
#  'Boggs': 4,
#  'Jackson': 4,
#  'Homes': 4,
#  'Mitchell': 4,
#  'Leeg 1': 4,
#  'Leeg 2': 4,
#  'Cressida': 4,
#  'Messala': 4,
#  'Pollux': 4,
#  'Castor': 4,
#  'Fulvia Cardew': 4,
#  'Paylor': 3,
#  'Lyme': 4,
#  'Presidente Ravinstill': 4,
#  'Volumnia': 4,
#  'Felix': 4,
#  'Plutarch': 3,
#  'Seneca': 3,
#  'Hilarius': 3,
#  'Trajan': 4,
#  'Alma': 3,
#  'Thresh': 4,
#  'Marina': 4,
# ...

# %%
sorted(nx.closeness_centrality(g).items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Coriolanus', 0.6478260869565218),
#  ('Katniss', 0.6394849785407726),
#  ('Caesar', 0.5359712230215827),
#  ('Plutarch', 0.5209790209790209),
#  ('Tigris', 0.5155709342560554),
#  ('Sra Everdeen', 0.5016835016835017),
#  ('Alma', 0.49337748344370863),
#  ('Peeta', 0.48220064724919093),
#  ('Gale', 0.4501510574018127),
#  ('Finnick', 0.4501510574018127),
#  ('Lucy Gray', 0.44744744744744747),
#  ('Hilarius', 0.4421364985163205),
#  ('Sejanus', 0.436950146627566),
#  ('Livia Cardew', 0.43567251461988304),
#  ('Arachne', 0.4257142857142857),
#  ('Beetee', 0.42450142450142453),
#  ('Cressida', 0.42450142450142453),
#  ('Felix', 0.42450142450142453),
#  ('Casca', 0.42450142450142453),
#  ('Pollux', 0.42329545454545453),
#  ('Juno', 0.42329545454545453),
#  ('Pliny', 0.42329545454545453),
#  ('Iphigenia', 0.42329545454545453),
#  ('Dennis', 0.42329545454545453),
#  ('Apollo', 0.42329545454545453),
#  ('Palmyra', 0.42329545454545453),
#  ('Florus', 0.42329545454545453),
# ...

# %%
sns.histplot(nx.closeness_centrality(g).values(), bins= 30)
plt.legend()
plt.title("Closeness Centrality Histogram")
plt.xlabel("Closeness Centrality")
plt.ylabel("Number of Nodes")
# Out:
# /tmp/ipykernel_11968/1951740535.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0, 0.5, 'Number of Nodes')

# %%
nx.diameter(g)
# Out:
# 4

# %%
nx.average_shortest_path_length(g)
# Out:
# 2.447874720357942

# %%
nx.radius(g)
# Out:
# 3

# %%
nx.degree_assortativity_coefficient(g)
# Out:
# -0.13748036076189693

# %%
nx.density(g)
# Out:
# 0.10514541387024609

# %%
sorted(nx.clustering(g).items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Primrose', 1.0),
#  ('Sr Mellark', 1.0),
#  ('Venia', 1.0),
#  ('Flavius', 1.0),
#  ('Rory', 1.0),
#  ('Vick', 1.0),
#  ('Purnia', 1.0),
#  ('Greasy Sae', 1.0),
#  ('Lavinia', 1.0),
#  ('Trajan', 1.0),
#  ('Demetria', 1.0),
#  ('Dalton', 1.0),
#  ('Wiress', 1.0),
#  ('Blight', 1.0),
#  ('Woof', 1.0),
#  ('Cecelia', 1.0),
#  ('Chaff', 1.0),
#  ('Seeder', 1.0),
#  ('Morphling#1', 1.0),
#  ('Morphling#2', 1.0),
#  ('Cashmere', 1.0),
#  ('Gloss', 1.0),
#  ('Enobaria', 1.0),
#  ('Brutus', 1.0),
#  ('Ma Plinth', 1.0),
#  ('Remus', 1.0),
#  ('Barb', 1.0),
#  ('Thresh', 0.9777777777777777),
#  ('Marina', 0.9777777777777777),
#  ('Boggs', 0.9743589743589743),
#  ('Clerk Clamine', 0.9523809523809523),
#  ('Tam Amber', 0.9523809523809523),
#  ('Maude', 0.9523809523809523),
#  ('Jason', 0.9393939393939394),
#  ('Foxface', 0.9393939393939394),
#  ('Clove', 0.9393939393939394),
#  ('Cato', 0.9393939393939394),
#  ('Glimmer', 0.9393939393939394),
#  ('Marvel', 0.9393939393939394),
# ...

# %%
sns.histplot(nx.clustering(g).values(), bins= 30)
plt.legend()
plt.title("Clustering Coefficient Histogram")
plt.xlabel("Clustering Coefficient")
plt.ylabel("Number of Nodes")
# Out:
# /tmp/ipykernel_11968/116735290.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0, 0.5, 'Number of Nodes')
